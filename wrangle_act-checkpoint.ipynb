# %% [markdown]
# <img src="WeRateDogs.JPG" width="500" height="100"/>
#
# # Twitter Data Wrangling & Analysis Project
# >
# >**WeRateDogs Twitter Archive**
# >
# >**by Mostafa Ahmed**

# %% [markdown]
# <h1><a herf='#toc'>Project TOC</a></h1>
#
# <h2><a herf='#wrangling'>Data Wrangling</a></h2>
# <ul><h3><a herf='#gathering'>Gathering Data</a></h3>
# <ol>
# <li><a href="#twitter_archive">Twitter Archive</a></li>
# <li><a href="#img_pred">Image Predections</a></li>
# <li><a href="#api">WeRateDogs Twitter API</a></li>
# </ol>
#
# <h3><a herf='#assessing'>Assessing Data</a></h3>
# <ul><h4><a herf='#visual'>Visual Assesment</a></h4>
# <h4><a herf='#programmatic'>Programmatic Assesment</a></h4>
# <h4><a herf='#findings'>Assesment Findings</a></h4>
#
# <ul><h5><a herf='#quality'>Quality</a></h5>
# <ol>
# <li><a href="#twitter_archive">Twitter Archive Table</a></li>
# <li><a href="#images_predections">Images Predections Table</a></li>
# <li><a href="#tweets">Tweets Table</a></li>
# </ol>
# <h5><a herf='#tidness'>Tidness</a></h5></ul>
# </ul>
#
# <h3><a herf='#Cleaning'>Cleaning Data</a></h3>
# <ul>                </ul>
# </ul>
#
# <h2><a herf='#storing_analysizing'>Data Storing & Analyzing</a></h2>
#
# <ul><h3><a herf='#storing'>Storing Data</a></h3>
#
# <h3><a herf='#analyzing'>Analyzing Data</a></h3>
#
# <h3><a herf='#visualizing'>Visualizing Data</a></h3></ul>
#
#
# <h2><a herf='#reporting'>Reporting</a></h2>
#
# <ul><h3><a herf='#wrangle_report'>Wrangling Efforts</a></h3>
#
# <h3><a herf='#analyses_report'>Data Analyses</a></h3></ul>
#
# </ul>

# %% [markdown]
# <h2><a herf='#gathering'>Gathering Data</a></h2>
#
# ### 1- Readin Twitter Archive

# %%
# Import liabraries
import numpy as np
import pandas as pd
import tweepy
from tweepy import OAuthHandler
import json
import timeit
from timeit import default_timer as timer
import requests
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
pd.set_option('display.max_colwidth', None)

# %%
# Load Twitter archive data into a DataFrame
twitter_arc = pd.read_csv(r'twitter-archive-enhanced.csv')

# %%
# Check if the file is loaded into the DataFrame 
twitter_arc.head(1)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None

# %%
twitter_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# ### 2- Downloading Image Predections File

# %%
# Assign folder name and creat one if not exist
folder_name = 'WeRateDogs'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Parsing url into a tsv file
url = ' https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open (os.path.join(folder_name, url.split('/')[-1]),
           mode='wb') as file:
    file.write(response.content)

# %%
# Check the contents pf WeRateDogs folder
os.listdir(folder_name)
# Out:
# ['image-predictions.tsv']

# %%
# Load image predections file into a DataFrame
img_pred = pd.read_csv(r'image-predictions.tsv', sep='\t')

# %%
# Check if the file is loaded into the DataFrame  
img_pred.head(1)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#    img_num                      p1   p1_conf  p1_dog      p2   p2_conf  \
# 0        1  Welsh_springer_spaniel  0.465074    True  collie  0.156665
#
#    p2_dog                 p3   p3_conf  p3_dog
# 0    True  Shetland_sheepdog  0.061428    True

# %%
img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ### 3- WeRateDogs Twitter API

# %% [markdown]
# https://docs.google.com/presentation/d/1KqevSqe6ygWVj4U-wlarKU7-SVR79x-vjpR4gEc4A9Q/edit?pli=1#slide=id.g1697c74a_1_758

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_arc.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
tweet_json_list = []
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            tweet_json_list.append(tweet._json)
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
#     Reading JSON from a file
# https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/

# %%
# Reading  api_df
df_list = []

with open('tweet_json.txt', 'r') as file:
    for line in file:
        data = json.loads(line)
        tweet_id = data['id']
        retweet_count = data['retweet_count']
        fav_count = data['favorite_count']
        user_count = data['user']['followers_count']
        df_list.append({'tweet_id':tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': fav_count,
                       'user_count': user_count})
        
json_df = pd.DataFrame(df_list)

# %%
json_df.head()
# Out:
#              tweet_id  retweet_count  favorite_count  user_count
# 0  892420643555336193           7343           34994     8978318
# 1  892177421306343426           5479           30299     8978318
# 2  891815181378084864           3623           22789     8978318
# 3  891689557279858688           7532           38257     8978318
# 4  891327558926688256           8113           36537     8978318

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2326 non-null   int64
#  1   retweet_count   2326 non-null   int64
#  2   favorite_count  2326 non-null   int64
#  3   user_count      2326 non-null   int64
# dtypes: int64(4)
# memory usage: 72.8 KB

# %%
# Save Json DataFrame to csv file
json_df.to_csv('tweet_json.csv', index=False)

# %% [markdown]
# <h3><a herf='#assessing'>Assessing Data</a></h3>
# <h4><a herf='#visual'>Visual Assesment</a></h4>
#
# #### 1- Twitter Archive Table

# %%
twitter_arc.head(25)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   892420643555336193                    NaN                  NaN
# 1   892177421306343426                    NaN                  NaN
# 2   891815181378084864                    NaN                  NaN
# 3   891689557279858688                    NaN                  NaN
# 4   891327558926688256                    NaN                  NaN
# 5   891087950875897856                    NaN                  NaN
# 6   890971913173991426                    NaN                  NaN
# 7   890729181411237888                    NaN                  NaN
# 8   890609185150312448                    NaN                  NaN
# 9   890240255349198849                    NaN                  NaN
# 10  890006608113172480                    NaN                  NaN
# 11  889880896479866881                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# ...

# %%
twitter_arc.tail(25)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2331  666353288456101888                    NaN                  NaN
# 2332  666345417576210432                    NaN                  NaN
# 2333  666337882303524864                    NaN                  NaN
# 2334  666293911632134144                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2336  666273097616637952                    NaN                  NaN
# 2337  666268910803644416                    NaN                  NaN
# 2338  666104133288665088                    NaN                  NaN
# 2339  666102155909144576                    NaN                  NaN
# 2340  666099513787052032                    NaN                  NaN
# 2341  666094000022159362                    NaN                  NaN
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# ...

# %%
twitter_arc.sample(25)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2290  667171260800061440                    NaN                  NaN
# 347   831911600680497154                    NaN                  NaN
# 1954  673656262056419329                    NaN                  NaN
# 704   785872687017132033                    NaN                  NaN
# 1363  702932127499816960                    NaN                  NaN
# 1819  676590572941893632           6.765883e+17         4.196984e+09
# 2256  667766675769573376                    NaN                  NaN
# 2308  666817836334096384                    NaN                  NaN
# 993   748575535303884801                    NaN                  NaN
# 942   752917284578922496                    NaN                  NaN
# 398   825026590719483904                    NaN                  NaN
# 1640  684147889187209216                    NaN                  NaN
# 1984  672902681409806336                    NaN                  NaN
# ...

# %% [markdown]
# #### 2- Image Predection Table

# %%
img_pred.head(25)
# Out:
#               tweet_id                                          jpg_url  \
# 0   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3   666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4   666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5   666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6   666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7   666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8   666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9   666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10  666063827256086533  https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11  666071193221509120  https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...

# %%
img_pred.tail(25)
# Out:
#                 tweet_id                                            jpg_url  \
# 2050  887343217045368832  https://pbs.twimg.com/ext_tw_video_thumb/88734...
# 2051  887473957103951883    https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
# 2052  887517139158093824  https://pbs.twimg.com/ext_tw_video_thumb/88751...
# 2053  887705289381826560    https://pbs.twimg.com/media/DFHDQBbXgAEqY7t.jpg
# 2054  888078434458587136    https://pbs.twimg.com/media/DFMWn56WsAAkA7B.jpg
# 2055  888202515573088257    https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
# 2056  888554962724278272    https://pbs.twimg.com/media/DFTH_O-UQAACu20.jpg
# 2057  888804989199671297    https://pbs.twimg.com/media/DFWra-3VYAA2piG.jpg
# 2058  888917238123831296    https://pbs.twimg.com/media/DFYRgsOUQAARGhO.jpg
# 2059  889278841981685760  https://pbs.twimg.com/ext_tw_video_thumb/88927...
# 2060  889531135344209921    https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg
# ...

# %%
img_pred.sample(25)
# Out:
#                 tweet_id                                            jpg_url  \
# 1535  790337589677002753    https://pbs.twimg.com/media/CvfX2AnWYAAQTay.jpg
# 1684  814153002265309185    https://pbs.twimg.com/media/C0xz04SVIAAeyDb.jpg
# 46    666804364988780544    https://pbs.twimg.com/media/CUD3A7YWoAA82N0.jpg
# 327   671896809300709376    https://pbs.twimg.com/media/CVMOlMiWwAA4Yxl.jpg
# 1219  743895849529389061    https://pbs.twimg.com/media/ClLZU8LWQAAsOxV.jpg
# 41    666701168228331520    https://pbs.twimg.com/media/CUCZLHlUAAAeAig.jpg
# 596   679527802031484928    https://pbs.twimg.com/media/CW4q7jDWkAA2y8g.jpg
# 598   679722016581222400    https://pbs.twimg.com/media/CW7bkW6WQAAksgB.jpg
# 1613  801958328846974976    https://pbs.twimg.com/media/CyEg2AXUsAA1Qpf.jpg
# 1513  786595970293370880    https://pbs.twimg.com/media/CuqM0fVWAAAboKR.jpg
# 1111  724046343203856385    https://pbs.twimg.com/media/CgxUTS_XEAAC0pv.jpg
# ...

# %% [markdown]
# #### 3- Tweets_Json  Table

# %%
json_df = pd.read_csv(r'tweet_json.csv')

# %%
json_df.head(25)
# Out:
#               tweet_id  retweet_count  favorite_count  user_count
# 0   892420643555336193           7343           34994     8978318
# 1   892177421306343426           5479           30299     8978318
# 2   891815181378084864           3623           22789     8978318
# 3   891689557279858688           7532           38257     8978318
# 4   891327558926688256           8113           36537     8978318
# 5   891087950875897856           2715           18427     8978318
# 6   890971913173991426           1757           10718     8978318
# 7   890729181411237888          16467           58952     8978318
# 8   890609185150312448           3768           25359     8978318
# 9   890240255349198849           6377           28942     8978318
# 10  890006608113172480           6405           27904     8978318
# 11  889880896479866881           4342           25377     8978318
# 12  889665388333682689           8730           43568     8978318
# ...

# %%
json_df.tail(25)
# Out:
#                 tweet_id  retweet_count  favorite_count  user_count
# 2301  666353288456101888             63             192     8978336
# 2302  666345417576210432            128             266     8978336
# 2303  666337882303524864             81             174     8978336
# 2304  666293911632134144            306             447     8978336
# 2305  666287406224695296             57             131     8978336
# 2306  666273097616637952             69             156     8978336
# 2307  666268910803644416             32              93     8978336
# 2308  666104133288665088           5728           13140     8978336
# 2309  666102155909144576             11              69     8978336
# 2310  666099513787052032             57             139     8978336
# 2311  666094000022159362             65             152     8978336
# 2312  666082916733198337             41             100     8978336
# 2313  666073100786774016            140             280     8978336
# ...

# %%
json_df.sample(25)
# Out:
#                 tweet_id  retweet_count  favorite_count  user_count
# 1140  722613351520608256           1556            4773     8978326
# 135   864873206498414592           7813           29802     8978318
# 940   750383411068534784           1097            4408     8978324
# 448   817415592588222464            924            5495     8978322
# 71    878604707211726852           6186           27364     8978318
# 1297  706265994973601792            889            2635     8978326
# 513   808134635716833280           5781               0     8978322
# 23    887343217045368832           9200           30570     8978318
# 1248  709198395643068416            610            2357     8978327
# 974   747963614829678593           2050            5580     8978325
# 1099  730196704625098752           1788            4636     8978325
# 1787  676617503762681856            894            2722     8978333
# 1371  699779630832685056           1181            2625     8978326
# ...

# %% [markdown]
# <h4><a herf='#programmatic'>Programmatic Assesment</a></h4>
#
# #### 1- Twitter Archive Table

# %%
twitter_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twitter_arc[twitter_arc.expanded_urls.isnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 185   856330835276025856                    NaN                  NaN
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# ...

# %%
twitter_arc[twitter_arc.retweeted_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1023  746521445350707200                    NaN                  NaN
# 1043  743835915802583040                    NaN                  NaN
# 1242  711998809858043904                    NaN                  NaN
# 2259  667550904950915073                    NaN                  NaN
# 2260  667550882905632768                    NaN                  NaN
#
#                       timestamp  \
# 19    2017-07-21 01:02:36 +0000
# 32    2017-07-15 02:45:48 +0000
# 36    2017-07-13 01:35:06 +0000
# ...

# %%
twitter_arc[twitter_arc.in_reply_to_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# ...                  ...                    ...                  ...
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 30    2017-07-15 16:51:35 +0000
# 55    2017-07-02 21:58:53 +0000
# 64    2017-06-27 12:14:36 +0000
# ...

# %%
twitter_arc[twitter_arc.retweeted_status_id.notnull() | twitter_arc.in_reply_to_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 55    881633300179243008           8.816070e+17         4.738443e+07
# ...                  ...                    ...                  ...
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2259  667550904950915073                    NaN                  NaN
# 2260  667550882905632768                    NaN                  NaN
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                       timestamp  \
# 19    2017-07-21 01:02:36 +0000
# 30    2017-07-15 16:51:35 +0000
# 32    2017-07-15 02:45:48 +0000
# ...

# %%
twitter_arc.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
twitter_arc[twitter_arc.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
twitter_arc[twitter_arc.source.duplicated()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# ...

# %%
twitter_arc.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twitter_arc[['doggo', 'floofer', 'pupper', 'puppo']].value_counts()
# Out:
# doggo  floofer  pupper  puppo
# None   None     None    None     1976
#                 pupper  None      245
# doggo  None     None    None       83
# None   None     None    puppo      29
# doggo  None     pupper  None       12
# None   floofer  None    None        9
# doggo  floofer  None    None        1
#        None     None    puppo       1
# dtype: int64

# %%
twitter_arc[(twitter_arc.floofer == 'floofer') & (twitter_arc.doggo == 'doggo')]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760                    NaN                  NaN
#
#                      timestamp  \
# 200  2017-04-17 16:34:26 +0000
#
#                                                                                  source  \
# 200  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                      text  \
# 200  At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk
#
#      retweeted_status_id  retweeted_status_user_id retweeted_status_timestamp  \
# 200                  NaN                       NaN                        NaN
#
# ...

# %%
twitter_arc[(twitter_arc.pupper == 'pupper') & (twitter_arc.doggo == 'doggo')]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 460   817777686764523521                    NaN                  NaN
# 531   808106460588765185                    NaN                  NaN
# 565   802265048156610565           7.331095e+17         4.196984e+09
# 575   801115127852503040                    NaN                  NaN
# 705   785639753186217984                    NaN                  NaN
# 733   781308096455073793                    NaN                  NaN
# 778   775898661951791106                    NaN                  NaN
# 822   770093767776997377                    NaN                  NaN
# 889   759793422261743616                    NaN                  NaN
# 956   751583847268179968                    NaN                  NaN
# 1063  741067306818797568                    NaN                  NaN
# 1113  733109485275860992                    NaN                  NaN
#
#                       timestamp  \
# 460   2017-01-07 16:59:28 +0000
# ...

# %%
twitter_arc.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
twitter_arc.text[twitter_arc.rating_denominator != 10].count()
# Out:
# 23

# %%
twitter_arc[twitter_arc.rating_denominator != 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %%
twitter_arc.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
twitter_arc[twitter_arc.rating_numerator > 20]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 340   832215909146226688                    NaN                  NaN
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 763   778027034220126208                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 979   749981277374128128                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# ...

# %%
twitter_arc[twitter_arc.rating_numerator > 20].rating_numerator.value_counts()
# Out:
# 420     2
# 75      2
# 60      1
# 27      1
# 99      1
# 165     1
# 80      1
# 144     1
# 204     1
# 45      1
# 88      1
# 143     1
# 1776    1
# 44      1
# 50      1
# 26      1
# 84      1
# 182     1
# 24      1
# 121     1
# 666     1
# 960     1
# Name: rating_numerator, dtype: int64

# %%
twitter_arc.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
# ...

# %%
wrong_names =['None', 'such', 'quite'] 
twitter_arc[(twitter_arc.name.str.contains('|'.join(wrong_names), case=False)) 
            | (twitter_arc.name == 'a')
            | (twitter_arc.name == 'an')
            | (twitter_arc.name == 'by')
            | (twitter_arc.name == 'old')
            | (twitter_arc.name == 'not')
            | (twitter_arc.name == 'my')
            | (twitter_arc.name == 'all')].name.value_counts()
# Out:
# None     745
# a         55
# an         7
# quite      4
# not        2
# old        1
# all        1
# such       1
# by         1
# my         1
# Name: name, dtype: int64

# %%
twitter_arc[(twitter_arc.name.str.contains('|'.join(wrong_names), case=False)) 
            | (twitter_arc.name == 'a')
            | (twitter_arc.name == 'an')
            | (twitter_arc.name == 'by')
            | (twitter_arc.name == 'old')
            | (twitter_arc.name == 'not')
            | (twitter_arc.name == 'my')
            | (twitter_arc.name == 'all')]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 22    887517139158093824                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# ...

# %% [markdown]
# #### 2- Image Predection Table

# %%
img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
img_pred[img_pred.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
img_pred.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
img_pred.p1.unique()
# Out:
# array(['Welsh_springer_spaniel', 'redbone', 'German_shepherd',
#        'Rhodesian_ridgeback', 'miniature_pinscher',
#        'Bernese_mountain_dog', 'box_turtle', 'chow', 'shopping_cart',
#        'miniature_poodle', 'golden_retriever', 'Gordon_setter',
#        'Walker_hound', 'pug', 'bloodhound', 'Lhasa', 'English_setter',
#        'hen', 'desktop_computer', 'Italian_greyhound', 'Maltese_dog',
#        'three-toed_sloth', 'ox', 'malamute', 'guinea_pig',
#        'soft-coated_wheaten_terrier', 'Chihuahua',
#        'black-and-tan_coonhound', 'coho', 'toy_terrier',
#        'Blenheim_spaniel', 'Pembroke', 'llama',
#        'Chesapeake_Bay_retriever', 'curly-coated_retriever', 'dalmatian',
#        'Ibizan_hound', 'Border_collie', 'Labrador_retriever', 'seat_belt',
#        'snail', 'miniature_schnauzer', 'Airedale', 'triceratops', 'swab',
#        'hay', 'hyena', 'jigsaw_puzzle', 'West_Highland_white_terrier',
# ...

# %%
img_pred[img_pred.p1_dog == False].sample(25)
# Out:
#                 tweet_id  \
# 1979  870804317367881728
# 1198  740699697422163968
# 1848  839549326359670784
# 1416  771136648247640064
# 1036  711968124745228288
# 856   696754882863349760
# 986   707693576495472641
# 1431  773247561583001600
# 1936  860184849394610176
# 806   691820333922455552
# 1549  792913359805018113
# 1270  749981277374128128
# 1297  752309394570878976
# 163   668960084974809088
# 669   683078886620553216
# 553   677573743309385728
# 321   671855973984772097
# 576   678675843183484930
# 284   671141549288370177
# 1517  787322443945877504
# 296   671362598324076544
# 1931  859074603037188101
# 1154  732732193018155009
# 293   671347597085433856
# 1630  805487436403003392
#
#                                                                                       jpg_url  \
# 1979                                          https://pbs.twimg.com/media/DBW35ZsVoAEWZUU.jpg
# 1198                                          https://pbs.twimg.com/media/Ckd-bqVUkAIiyM7.jpg
# ...

# %%
img_pred.p1_dog.value_counts()
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64

# %% [markdown]
# #### 3- Tweets_Json  Table

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2326 non-null   int64
#  1   retweet_count   2326 non-null   int64
#  2   favorite_count  2326 non-null   int64
#  3   user_count      2326 non-null   int64
# dtypes: int64(4)
# memory usage: 72.8 KB

# %%
json_df[json_df.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, retweet_count, favorite_count, user_count]
# Index: []

# %%
json_df.describe()
# Out:
#            tweet_id  retweet_count  favorite_count    user_count
# count  2.326000e+03    2326.000000     2326.000000  2.326000e+03
# mean   7.419794e+17    2584.320292     7319.568788  8.978331e+06
# std    6.824846e+16    4372.181837    11358.007218  5.094983e+01
# min    6.660209e+17       1.000000        0.000000  8.978318e+06
# 25%    6.783361e+17     526.000000     1273.500000  8.978323e+06
# 50%    7.183508e+17    1206.000000     3170.000000  8.978325e+06
# 75%    7.986802e+17    2993.500000     8953.250000  8.978331e+06
# max    8.924206e+17   74209.000000   150397.000000  8.978898e+06

# %%
json_df[json_df.favorite_count == 0]
# Out:
#                 tweet_id  retweet_count  favorite_count  user_count
# 31    886054160059072513             96               0     8978318
# 35    885311592912609280          16128               0     8978318
# 67    879130579576475649           5973               0     8978318
# 72    878404777348136964           1117               0     8978318
# 73    878316110768087041           5793               0     8978318
# ...                  ...            ...             ...         ...
# 997   746521445350707200            941               0     8978325
# 1017  743835915802583040           1975               0     8978325
# 1216  711998809858043904            123               0     8978326
# 2229  667550904950915073             30               0     8978336
# 2230  667550882905632768             26               0     8978336
#
# [162 rows x 4 columns]

# %%
json_df[json_df.retweet_count == 1]
# Out:
#                tweet_id  retweet_count  favorite_count  user_count
# 279  838085839343206401              1             136     8978322

# %%
twitter_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# <h3><a herf='#findings'>Assesment Findings</a></h3>

# %% [markdown]
# ### Quality issues
#
#
# #### Twitter archive table
#
# - Missing 59 expanded_urls and non recoverable. ***(can't clean)***
# - 181 retweet records need to be dropped as our scope is the original tweets onlly
# - 78 reply records that is not in the analyses scope and need to be drooped
# - 1 record with 2 stages (doggo, floofer)
# - 12 record with 2 stages (pupper, doggo )
# - 73 record with wrong dog names as below:
# |Wrong name|count|
# |--|--|
# |a|55|
# |an|7|
# |quite|4|
# |not|2|
# |old|1|
# |all|1|
# |such|1|
# |by|1|
# |my|1|
#
# - Missing name info for 745 record (with value 'None').
# - 23 recoed with rating denominator not equal to 10
# - 24 record with rating nominator more than 20 (i.e 420, 960, 666, 1776), which some of these records has a valid
# - Erroneous datatypes (float not an integer) for (in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id columns).
# - As there  is only 4 sources in source column, I belive datatype should be changed from a string to a category.
# - Stages (doggo, floofer, pupper, puppo) is obeject not a ctegory (will be addressed in Tidiness section)
# - New created column stages datatype is string, should be a ctegory
# - img_num column (merged from image predicting table) datatype is a float, should be an integer
# -  Columns merged from json_df table (retweet_count, favorite_count, user_count) are float, should be an integer
#
# #### Image predection table
#
# - 543 recodrs with not a dog predection such as ('fire_engine', ''toyshop', 'common_iguana', 'frilled_lizard', 'leatherback_turtle', 'hamster', 'trombone', 'canoe', 'king_penguin', 'shopping_basket', 'basenji', 'bearskin', 'crash_helmet','komondor', 'ski_mask', 'shower_curtain', 'basset', 'jellyfish', 'doormat', 'Arabian_camel','hog', 'comic_book', 'minivan','seashore', 'cuirass', 'Brabancon_griffon', 'candle', 'car_mirror', 'piggy_bank', 'pot', 'boathouse', 'mud_turtle') and else more, which should be cleaned
#
# - Missing records in image predection (2075) compared to Twitter archive count (2356) with 281 missing records***(can't clean)***
#
# #### Tweets Json table
#
# - Missing records in image predection (2326) compared to Twitter archive count (2356) with 30 missing records***(can't clean)***
#
# ### Tidiness  issues
#
# #### Twitter archive table
#
# - Retweet & reply related columns is not needed as our target is based on tweets only (can be dropped after retweet & reply records are dropped) as below:
#             in_reply_to_status_id
#             in_reply_to_user_id
#             retweeted_status_id
#             retweeted_status_user_id columns
#             retweeted_status_timestamp
#
# - doggo, floofer, pupper, puppo columns should be melted into a one classification column.
#
# #### Image prediction  table
#
# - Tweet_id in twitter archive table duplicated in Image prediction table, which should be merged to twitter archive table on tweet_id column
#
# - As Prediction  1 is the most accurate, columns starting from p2 column are not needed:
#                                                                     p2
#                                                                     p2_conf
#                                                                     p2_dog
#                                                                     p3
#                                                                     p3_conf
#                                                                     p3_dog
#
# #### Tweets Json table
#
# - Tweet_id in twitter archive table duplicated in tweets json table, which should be merged to  twitter archive table on tweet_id column

# %% [markdown]
# ## Cleaning
#
#     In cleaning process, I will go through the issues as the order below:
#         1- Quality completeness  issues
#         2- Tidness issues
#         3- Quality remaining issues

# %% [markdown]
# ### Quality Completeness issues

# %%
# Copy Dataframes to start cleaninig process
twitter_archive_clean = twitter_arc.copy()
img_predction_clean = img_pred.copy()
tweets_json_clean = json_df.copy()

# %% [markdown]
# #### 1.1- Define
# Drop 181 retweet records from `twitter_archive_clean` table with assigning it to the filtered records

# %% [markdown]
# #### 1.2- Code

# %%
twitter_archive_clean = twitter_archive_clean[~twitter_archive_clean.retweeted_status_id.notnull()]

# %% [markdown]
# #### 1.3- Test

# %%
# Check if there any retweet records 
twitter_archive_clean[twitter_archive_clean.retweeted_status_id.notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Confirm with the updated Dataframe info
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   object
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2175 non-null   object
# ...

# %% [markdown]
# #### 2.1- Define
# Drop 78 reply records from `twitter_archive_clean` table with assigning it to the filtered records

# %% [markdown]
# #### 2.2- Code

# %%
twitter_archive_clean = twitter_archive_clean[~twitter_archive_clean.in_reply_to_user_id.notnull()]

# %% [markdown]
# #### 2.3- Test

# %%
# Check if there any retweet records 
twitter_archive_clean[twitter_archive_clean.in_reply_to_user_id.notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Confirm with the updated Dataframe info
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2097 non-null   int64
#  1   in_reply_to_status_id       0 non-null      float64
#  2   in_reply_to_user_id         0 non-null      float64
#  3   timestamp                   2097 non-null   object
#  4   source                      2097 non-null   object
#  5   text                        2097 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2094 non-null   object
#  10  rating_numerator            2097 non-null   int64
#  11  rating_denominator          2097 non-null   int64
#  12  name                        2097 non-null   object
# ...

# %% [markdown]
# #### 3.1- Define
#
# Change 1 record with 2 stages (doggo, floofer) and 12 record with 2 stages (pupper, doggo ) to 'None' for the wrong stage using iloc and assign wrong value to 'None'

# %% [markdown]
# #### 3.2.1- Code

# %%
# Filter to determine the location of 2 stages (doggo, floofer)
twitter_archive_clean[(twitter_archive_clean.floofer == 'floofer') & (twitter_archive_clean.doggo == 'doggo')]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760                    NaN                  NaN
#
#                      timestamp  \
# 200  2017-04-17 16:34:26 +0000
#
#                                                                                  source  \
# 200  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                      text  \
# 200  At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk
#
#      retweeted_status_id  retweeted_status_user_id retweeted_status_timestamp  \
# 200                  NaN                       NaN                        NaN
#
# ...

# %%
# Change doggo value for the record to none
twitter_archive_clean.loc[200, 'doggo'] = 'None'

# %% [markdown]
# #### 3.3.1- Test

# %%
# Confirm the value has changed to 'None'
twitter_archive_clean[(twitter_archive_clean.floofer == 'floofer') & (twitter_archive_clean.doggo == 'doggo')]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
twitter_archive_clean.loc[200, 'doggo']
# Out:
# 'None'

# %% [markdown]
# #### 3.2.2- Code

# %%
# Filter to determine the location of 2 stages (doggo, floofer)
twitter_archive_clean[(twitter_archive_clean.pupper == 'pupper') & (twitter_archive_clean.doggo == 'doggo')]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 460   817777686764523521                    NaN                  NaN
# 531   808106460588765185                    NaN                  NaN
# 575   801115127852503040                    NaN                  NaN
# 705   785639753186217984                    NaN                  NaN
# 733   781308096455073793                    NaN                  NaN
# 889   759793422261743616                    NaN                  NaN
# 956   751583847268179968                    NaN                  NaN
# 1063  741067306818797568                    NaN                  NaN
# 1113  733109485275860992                    NaN                  NaN
#
#                       timestamp  \
# 460   2017-01-07 16:59:28 +0000
# 531   2016-12-12 00:29:28 +0000
# 575   2016-11-22 17:28:25 +0000
# 705   2016-10-11 00:34:48 +0000
# 733   2016-09-29 01:42:20 +0000
# 889   2016-07-31 16:50:42 +0000
# 956   2016-07-09 01:08:47 +0000
# ...

# %% [markdown]
# **Note:** after analyzing the tweets, I find out most tweets are for more one dog. This cleaning step was being conducted to avoide replacing any stage values when melting the stage columns into one column, but as i can not removing one of the two stages, I will leave it as it is and try to find workaround in melting stages columns.

# %% [markdown]
# #### 4.1- Define
#
# Drop 543 recodrs with *False* predection in *p1* column from `img_predection_clean` table with assigning it to the filtered records

# %% [markdown]
# #### 4.2- Code

# %%
img_predction_clean = img_predction_clean[img_predction_clean.p1_dog == True]

# %% [markdown]
# #### 4.3- Test

# %%
# Check if there any predection with False value
img_predction_clean[img_predction_clean.p1_dog == False]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
# Confirm with value counts
img_predction_clean.p1_dog.value_counts()
# Out:
# True    1532
# Name: p1_dog, dtype: int64

# %% [markdown]
# ### Tidiness issues

# %% [markdown]
# #### 5.1- Define
#
# - Drop retweet & reply related columns in `twitter_archive_clean` table , which is not needed as our target is based on tweets only (can be dropped after retweet & reply records are dropped) as below:
#             in_reply_to_status_id
#             in_reply_to_user_id
#             retweeted_status_id
#             retweeted_status_user_id
#             retweeted_status_timestamp

# %% [markdown]
# #### 5.2- Code

# %%
twitter_archive_clean.drop(['in_reply_to_status_id',
                            'in_reply_to_user_id', 
                            'retweeted_status_id', 
                            'retweeted_status_user_id', 
                            'retweeted_status_timestamp'], axis='columns', inplace=True)

# %% [markdown]
# #### 5.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 293.0+ KB

# %% [markdown]
# #### 6.1- Define
#
# Melt doggo, floofer, pupper, puppo columns in `twitter_archive_clean` table into one *stages* column.

# %% [markdown]
# #### 6.2- Code

# %%
# Rplace 'None' value in doggo, floofer, pupper, puppo columns
twitter_archive_clean.doggo.replace('None','', inplace=True)
twitter_archive_clean.floofer.replace('None','', inplace=True)
twitter_archive_clean.pupper.replace('None','', inplace=True)
twitter_archive_clean.puppo.replace('None','', inplace=True)

# %%
# Check the value count of 'None'
print(twitter_archive_clean.doggo.value_counts(), '\n',
twitter_archive_clean.floofer.value_counts(), '\n',
twitter_archive_clean.pupper.value_counts(), '\n',
twitter_archive_clean.puppo.value_counts())
# Out:
#          2015
# doggo      82
# Name: doggo, dtype: int64
#             2087
# floofer      10
# Name: floofer, dtype: int64
#            1867
# pupper     230
# Name: pupper, dtype: int64
#           2073
# puppo      24
# Name: puppo, dtype: int64

# %%
# Creat new 'stages' column as a sum of doggo, floofer, pupper, puppo columns
twitter_archive_clean['stages'] = twitter_archive_clean.apply(lambda row: row['doggo'] +
                                                              row['floofer']+ row['pupper']+
                                                              row['puppo'], axis=1).str.strip()

# %%
# Check the value count of the new stage column
twitter_archive_clean.stages.value_counts()
# Out:
#                1761
# pupper          221
# doggo            72
# puppo            23
# floofer          10
# doggopupper       9
# doggopuppo        1
# Name: stages, dtype: int64

# %%
# Replace 'doggopupper' with 'doggo&pupper' and 'doggopuppo' with 'doggo&puppo'
twitter_archive_clean.stages.replace('doggopupper', 'doggo&pupper', inplace=True)
twitter_archive_clean.stages.replace('doggopuppo', 'doggo&puppo', inplace=True)

# %%
# Check the value count of the stage after replacing the values
twitter_archive_clean.stages.value_counts()
# Out:
#                 1761
# pupper           221
# doggo             72
# puppo             23
# floofer           10
# doggo&pupper       9
# doggo&puppo        1
# Name: stages, dtype: int64

# %%
# Drop doggo, floofer, pupper, puppo columns when done
twitter_archive_clean.drop(['floofer',
                            'pupper', 
                            'puppo', 
                            'doggo'], axis='columns', inplace=True)

# %%
# Change stages column empty value with Nan
twitter_archive_clean.stages.replace('', np.nan, inplace=True)

# %% [markdown]
# #### 6.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 243.8+ KB

# %% [markdown]
# #### 7.1- Define
#
# - Drop below columns `img_predction_clean` as 1st Predcion (p1) is the most accurate:
#                                                                     p2
#                                                                     p2_conf
#                                                                     p2_dog
#                                                                     p3
#                                                                     p3_conf
#                                                                     p3_dog

# %% [markdown]
# #### 7.2- Code

# %%
img_predction_clean.drop(['p2',
                        'p2_conf', 
                        'p2_dog', 
                        'p3', 
                        'p3_conf',
                        'p3_dog'], axis='columns', inplace=True)

# %% [markdown]
# #### 7.3- Test

# %%
img_predction_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1532 entries, 0 to 2073
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  1532 non-null   int64
#  1   jpg_url   1532 non-null   object
#  2   img_num   1532 non-null   int64
#  3   p1        1532 non-null   object
#  4   p1_conf   1532 non-null   float64
#  5   p1_dog    1532 non-null   bool
# dtypes: bool(1), float64(1), int64(2), object(2)
# memory usage: 73.3+ KB

# %% [markdown]
# #### 8.1- Define
#
# Merge `img_predction_clean` to `twitter_archive_clean`  table on tweet_id column

# %% [markdown]
# #### 8.2- Code

# %%
twitter_archive_clean = pd.merge(twitter_archive_clean, img_predction_clean, on=['tweet_id'], how='left')

# %% [markdown]
# #### 8.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    object
#  9   jpg_url             1463 non-null   object
#  10  img_num             1463 non-null   float64
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 245.7+ KB

# %%
twitter_archive_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# #### 9.1- Define
#
# Merge `tweets_json_clean` to `twitter_archive_clean` on tweet_id column

# %% [markdown]
# #### 9.2- Code

# %%
twitter_archive_clean = pd.merge(twitter_archive_clean, tweets_json_clean, on=['tweet_id'], how='left')

# %% [markdown]
# #### 9.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    object
#  9   jpg_url             1463 non-null   object
#  10  img_num             1463 non-null   float64
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
#  14  retweet_count       2086 non-null   float64
# ...

# %%
twitter_archive_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
# ...

# %% [markdown]
# ### Remaining Quality issues

# %% [markdown]
# #### 10.1- Define
# The below issue is done already with dropping these column in Tidiness section:
# - Erroneous datatypes (float not an integer) for (in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id columns).

# %% [markdown]
# #### 11.1- Define
# - Save the original source values to a dictionary and convert if to a datframe
# - Replace source values with key values
# - Change source column from a string to a category.

# %% [markdown]
# #### 11.2- Code

# %%
source_dict={'source_key': ['iPhone', 'Vine', 'Web_Client', 'TweetDeck'], 
             'source_value': ['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 
            '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
            '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
           '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>']}
source_df = pd.DataFrame.from_dict(source_dict)

# %%
# Confirm the frame is built correctly
source_df
# Out:
#    source_key  \
# 0      iPhone
# 1        Vine
# 2  Web_Client
# 3   TweetDeck
#
#                                                                           source_value
# 0   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1                      <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
# 2                   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3  <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>

# %%
# Save source DataFrame to a csv file
source_df.to_csv('tweets_source.csv', index=False)

# %%
# Replace source values with key values
twitter_archive_clean.source.replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
                                     'iPhone', inplace=True)
twitter_archive_clean.source.replace('<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>', 'Vine',
                                     inplace=True)
twitter_archive_clean.source.replace('<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Web_Client',
                                     inplace=True)
twitter_archive_clean.source.replace('<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
                                     'TweetDeck', inplace=True)

# %%
# Change source column from a string to a category.
twitter_archive_clean.source = twitter_archive_clean.source.astype('category')

# %% [markdown]
# #### 11.3- Test

# %%
twitter_archive_clean.source.value_counts()
# Out:
# iPhone        1964
# Vine            91
# Web_Client      31
# TweetDeck       11
# Name: source, dtype: int64

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   category
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    object
#  9   jpg_url             1463 non-null   object
#  10  img_num             1463 non-null   float64
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
#  14  retweet_count       2086 non-null   float64
# ...

# %% [markdown]
# #### 12.1- Define
# Change new *stages* column in `twitter_archive_clean` table from a string to a category

# %% [markdown]
# #### 12.2- Code

# %%
twitter_archive_clean.stages = twitter_archive_clean.stages.astype('category')

# %% [markdown]
# #### 12.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   category
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    category
#  9   jpg_url             1463 non-null   object
#  10  img_num             1463 non-null   float64
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
#  14  retweet_count       2086 non-null   float64
# ...

# %% [markdown]
# #### 13.1- Define
# Change *img_num* column(merged from `imag_pred` table) and *retweet_count*, *favorite_count*, *user_count* columns(merged from `json_df` table) datatype from a float to an integer

# %% [markdown]
# #### 13.2- Code

# %%
# Replace Nan Values with 0
twitter_archive_clean.img_num.fillna(0, inplace=True)
twitter_archive_clean.retweet_count.fillna(0, inplace=True)
twitter_archive_clean.favorite_count.fillna(0, inplace=True)
twitter_archive_clean.user_count.fillna(0, inplace=True)

# Change columns data type tp an integer
twitter_archive_clean.img_num = twitter_archive_clean.img_num.astype(int)
twitter_archive_clean.retweet_count = twitter_archive_clean.retweet_count.astype(int)
twitter_archive_clean.favorite_count = twitter_archive_clean.favorite_count.astype(int)
twitter_archive_clean.user_count = twitter_archive_clean.user_count.astype(int)

# %% [markdown]
# #### 13.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   category
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    category
#  9   jpg_url             1463 non-null   object
#  10  img_num             2097 non-null   int32
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
#  14  retweet_count       2097 non-null   int32
# ...

# %% [markdown]
# #### 14.1- Define
# Change *timestamp* datatype from a string to an datetime

# %% [markdown]
# #### 14.2- Code

# %%
 twitter_archive_clean.timestamp = pd.to_datetime(twitter_archive_clean.timestamp)

# %% [markdown]
# #### 14.3- Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   datetime64[ns, UTC]
#  2   source              2097 non-null   category
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   stages              336 non-null    category
#  9   jpg_url             1463 non-null   object
#  10  img_num             2097 non-null   int32
#  11  p1                  1463 non-null   object
#  12  p1_conf             1463 non-null   float64
#  13  p1_dog              1463 non-null   object
#  14  retweet_count       2097 non-null   int32
# ...

# %% [markdown]
# ## Storing Data

# %%
twitter_archive_clean.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# ## Analyzing & Visualizing

# %% [markdown]
# ### Overall Analyses & Visualize

# %%
twitter_archive_clean.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator      img_num  \
# count  2.097000e+03       2097.000000         2097.000000  2097.000000
# mean   7.365594e+17         12.189318           10.448736     0.845970
# std    6.710178e+16         40.364996            6.645061     0.734655
# min    6.660209e+17          0.000000            2.000000     0.000000
# 25%    6.768197e+17         10.000000           10.000000     0.000000
# 50%    7.098528e+17         11.000000           10.000000     1.000000
# 75%    7.877176e+17         12.000000           10.000000     1.000000
# max    8.924206e+17       1776.000000          170.000000     4.000000
#
#            p1_conf  retweet_count  favorite_count    user_count
# count  1463.000000    2097.000000     2097.000000  2.097000e+03
# mean      0.615043    2403.208870     8038.274678  8.931235e+06
# std       0.260249    4219.719784    11725.812490  6.487155e+05
# min       0.044333       0.000000        0.000000  0.000000e+00
# ...

# %%
pd.plotting.scatter_matrix(twitter_archive_clean, figsize=(20, 20));

# %% [markdown]
# ### Source Portion
# Portion of each source of tweets
#
# As we can see below, most of the tweets comes from iPhone owners with **93.66%** followed by Vine with **4.33%**

# %%
twitter_archive_clean.e'])['groupby(['sourctweet_id'].count()/twitter_archive_clean.tweet_id.count()*100
# Out:
# source
# TweetDeck      0.524559
# Vine           4.339533
# Web_Client     1.478302
# iPhone        93.657606
# Name: tweet_id, dtype: float64

# %%
colors = ['darkred', 'white', 'green', 'orange']
counts = twitter_archive_clean.groupby(['source'])['tweet_id'].count()/twitter_archive_clean.tweet_id.count()*100
counts.plot(kind='bar', color=colors, edgecolor='darkgray', alpha=.7);
plt.title('Source Portion', fontsize=20);
plt.xlabel('Tweet Source', fontsize=12);
plt.ylabel('Count', fontsize=12);
fig = plt.gcf() 
fig.savefig('source_portion.png')

# %% [markdown]
# ### Most Popular Dog names
# What is the Most popular dog names among the tweets?
#
# As may dog name vakues is ('None'), I tighten the cretria to get the most populare *correct names*

# %%
df_names = twitter_archive_clean.groupby('name').filter(lambda x: 50 >= len(x) >= 9)
df_names.name.value_counts()
# Out:
# Lucy       11
# Charlie    11
# Cooper     10
# Oliver     10
# Tucker      9
# Penny       9
# Name: name, dtype: int64

# %%
df_names = twitter_archive_clean.groupby('name').filter(lambda x: 50 >= len(x) >= 9)
df_names['name'].value_counts().plot(kind = 'barh')
plt.title('Most Popular Dog Names', fontsize=20)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Dog Name', fontsize=12)

fig = plt.gcf() 
fig.savefig('dog_names.png');

# %% [markdown]
# ### Top 10 Preeds by Tweets count

# %%
twitter_archive_clean.groupby('p1').count()['rating_numerator'].nlargest(10)
# Out:
# p1
# golden_retriever      137
# Labrador_retriever     94
# Pembroke               88
# Chihuahua              78
# pug                    54
# chow                   41
# Samoyed                40
# Pomeranian             38
# toy_poodle             37
# malamute               29
# Name: rating_numerator, dtype: int64

# %%
twitter_archive_clean.groupby('p1').count()['rating_numerator'].nlargest(10).plot(kind='barh', color='darkred');
plt.title("Top 10 Breeds of Dog by Tweets count",fontsize=20)
plt.ylabel("Dog Breed",fontsize=12)
plt.xlabel("Number of Tweets",fontsize=12);
fig = plt.gcf() 
fig.savefig('dog_breeds.png');

# %% [markdown]
# Looks like the Golden Retriver is the most dog breed has been tweeted for back then.

# %%
twitter_archive_clean[twitter_archive_clean.p1 == 'golden_retriever' & ]
# Out:
#                 tweet_id                 timestamp  source  \
# 14    889531135344209921 2017-07-24 17:02:04+00:00  iPhone
# 16    888917238123831296 2017-07-23 00:22:39+00:00  iPhone
# 17    888804989199671297 2017-07-22 16:56:37+00:00  iPhone
# 41    883482846933004288 2017-07-08 00:28:19+00:00  iPhone
# 43    883117836046086144 2017-07-07 00:17:54+00:00  iPhone
# ...                  ...                       ...     ...
# 2028  667182792070062081 2015-11-19 03:29:07+00:00  iPhone
# 2034  667160273090932737 2015-11-19 01:59:39+00:00  iPhone
# 2042  667044094246576128 2015-11-18 18:17:59+00:00  iPhone
# 2073  666345417576210432 2015-11-16 20:01:42+00:00  iPhone
# 2086  666063827256086533 2015-11-16 01:22:45+00:00  iPhone
#
#                                                                                                                                                           text  \
# ...
